# %%
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import model_from_json
from tensorflow.keras import layers, models
import keras_tuner as kt
from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# import warnings
import warnings
# filter warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm

from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from tensorflow.keras.utils import to_categorical

import tensorflow as tf
from keras.preprocessing import image

import gc

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # 1. Import Data

# %%
styles_df = pd.read_csv('fashion-dataset/styles.csv',on_bad_lines='skip')
styles_df.index=styles_df['id']
styles_df.drop('id',axis=1,inplace=True)
styles_df.isna().sum()
# Out:
# gender                  0
# masterCategory          0
# subCategory             0
# articleType             0
# baseColour             15
# season                 21
# year                    1
# usage                 317
# productDisplayName      7
# dtype: int64

# %%
styles_df.masterCategory.value_counts()
# Out:
# masterCategory
# Apparel           21397
# Accessories       11274
# Footwear           9219
# Personal Care      2403
# Free Items          105
# Sporting Goods       25
# Home                  1
# Name: count, dtype: int64

# %%
g=sns.countplot(x=styles_df['masterCategory'])
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, 'Apparel'),
#  Text(1, 0, 'Accessories'),
#  Text(2, 0, 'Footwear'),
#  Text(3, 0, 'Personal Care'),
#  Text(4, 0, 'Free Items'),
#  Text(5, 0, 'Sporting Goods'),
#  Text(6, 0, 'Home')]

# %%
styles_df[styles_df['masterCategory']=='Home']
# Out:
#        gender masterCategory      subCategory     articleType baseColour  \
# id
# 40826  Unisex           Home  Home Furnishing  Cushion Covers     Yellow
#
#       season    year usage                                 productDisplayName
# id
# 40826   Fall  2012.0  Home  Swayam Unisex Yellow and Orange Cushion Covers...

# %% [markdown]
# ## 1.1 small classes

# %%
cats=styles_df.masterCategory.value_counts().sort_values(ascending=False).index

# %%
keep_df_sml_cls=styles_df[styles_df['masterCategory'].isin(cats[4:len(cats)])]

# %%
keep_df_sml_cls.shape
# Out:
# (131, 9)

# %%
keep_df_sml_cls['masterCategory'].replace({'Apparel':0,'Accessories':1,'Footwear':2,'Personal Care':3,
                                     'Free Items':4,'Sporting Goods':5,'Home':6},inplace=True)

# %%
prod_id_sml_cls = keep_df_sml_cls.index.to_numpy()

# %%
len(prod_id_sml_cls)
# Out:
# 131

# %%
prod_id_sml_cls[0:10]
# Out:
# array([53598, 49696, 53591, 45894, 53596, 52676, 29975, 29981, 51091,
#        54970], dtype=int64)

# %% [markdown]
# ## 1.2 Import Images for small classes

# %%
image_path = 'fashion-dataset/images/'

IMG_SIZE = 224

# %%
def load_imgs(names):
    imgs = []
    for i, image_name in enumerate(tqdm(names)):
#         if i% 50 == 0 :
#             print(f"Loading Image {i}")
        try:
            img = image.load_img(f'{image_path}{image_name}.jpg', color_mode='rgb',target_size=(IMG_SIZE, IMG_SIZE))
        except:
            img = None
        if img is None:
            print(image_name)
            continue
            
        img = np.array(img)
        imgs.append(img)
    return np.array(imgs)

# %%
images_sml_cls = load_imgs(prod_id_sml_cls)

# %%
images_sml_cls.shape
# Out:
# (0,)

# %%
gc.collect()
# Out:
# 50

# %%
# plot some image

img = images_sml_cls[0]
plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## 1.3 Apply ImageDataGenerator on small classes

# %%
import random, os

def set_seed(seed=123):
    np.random.seed(seed) 
    tf.random.set_seed(seed) 
    random.seed(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = "1"
    os.environ['TF_CUDNN_DETERMINISM'] = "1"
    os.environ['PYTHONHASHSEED'] = str(seed)

# %%
datagen = ImageDataGenerator(width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             rotation_range=50,
                             brightness_range=[0.15,2.0],
                             zoom_range=[5,0.5])

# %%
set_seed(seed=123)
x_batch_1, y_batch_1=datagen.flow(images_sml_cls,keep_df_sml_cls.masterCategory, 
                              batch_size=100, save_to_dir='fashion-dataset/gen_images/').next()

# %%
set_seed(seed=42)
x_batch_2, y_batch_2=datagen.flow(images_sml_cls,keep_df_sml_cls.masterCategory, 
                              batch_size=100, save_to_dir='fashion-dataset/gen_images/').next()

# %%
images_gen=np.vstack((x_batch_1,x_batch_2))
y_gen=np.hstack((y_batch_1,y_batch_2))

# %%
images_gen=images_gen.astype('uint8')

# %%
images_gen.dtype
# Out:
# dtype('uint8')

# %%
# plot some samples
img = images_gen[3]
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
i_gen=0

if i_gen==1:
    set_seed(seed=123)
    j=0
    for x_batch, y_batch in datagen.flow(images_sml_cls,keep_df_sml_cls.masterCategory, 
                                         batch_size=32, save_to_dir='fashion-dataset/gen_images/'):
        
        if j==0:
            images_gen=x_batch
            y_gen=y_batch
        if j>0:
            images_gen=np.vstack((images_gen,x_batch))
            y_gen=np.concatenate((y_gen,y_batch))
        
        if j>3:
        #if j>= len(images_sml_cls) / 32:
            break
        j=+1

# %%
images_sml_cls=np.vstack((images_sml_cls,images_gen))
y_sml_cls=np.concatenate((keep_df_sml_cls.masterCategory.values,y_gen))

# %%
images_sml_cls.shape
# Out:
# (331, 224, 224, 3)

# %%
gc.collect()
# Out:
# 4246

# %% [markdown]
# ## 1.4 Select 1000 Images from Each large classes

# %%
keep_df_lrg_cls=pd.DataFrame()
for i in range(4):
    idx = styles_df[styles_df['masterCategory']==cats[i]].sample(1000,random_state=42).index
    keep_df_lrg_cls=pd.concat([keep_df_lrg_cls,styles_df.loc[idx.values,:]])
#
keep_df_lrg_cls.shape
# Out:
# (4000, 9)

# %%
keep_df_lrg_cls['masterCategory'].replace({'Apparel':0,'Accessories':1,'Footwear':2,'Personal Care':3,
                                     'Free Items':4,'Sporting Goods':5,'Home':6},inplace=True)

# %%
prod_id_lrg_cls = keep_df_lrg_cls.index.to_numpy()

# %%
len(prod_id_lrg_cls)
# Out:
# 4000

# %% [markdown]
# ## 1.5 Import Images for large classes

# %%
images_lrg_cls = load_imgs(prod_id_lrg_cls)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4000/4000 [01:25<00:00, 46.76it/s]

# %%
gc.collect()
# Out:
# 0

# %%
images_lrg_cls.shape
# Out:
# (4000, 224, 224, 3)

# %% [markdown]
# # 2. Train_Test split

# %%
X=np.vstack((images_sml_cls,images_lrg_cls))

# %%
y=np.concatenate((y_sml_cls,keep_df_lrg_cls.masterCategory.values))

# %%
y.shape
# Out:
# (4331,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=123, test_size = 0.2)
print(X_train.shape, X_test.shape)
print(y_train.shape,y_test.shape)
# Out:
# (3464, 224, 224, 3) (867, 224, 224, 3)
# (3464,) (867,)

# %%
# plot some samples
img = X_train[0]
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
y_train=to_categorical(y_train, num_classes=7)
y_test=to_categorical(y_test, num_classes=7)

# %%
X_train= preprocess_input(X_train) 
X_test= preprocess_input(X_test)

# %%
np.save('X_train', X_train)

# %%
np.save('X_test', X_test)

# %%
np.save('y_train', y_train)

# %%
np.save('y_test', y_test)

# %%
y_test[0]
# Out:
# array([0., 0., 0., 1., 0., 0., 0.], dtype=float32)

# %% [markdown]
# # 3. Build Model

# %% [markdown]
# ## Load train/test data

# %%
i_load_X=1

if i_load_X==1:
    X_train = np.load('X_train.npy')
    X_test = np.load('X_test.npy')
    y_train = np.load('y_train.npy')
    y_test = np.load('y_test.npy')

# %% [markdown]
# ## Check distribution of masterCategory in Train Data

# %%
np.unique(argmax(y_train,axis=1),return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6], dtype=int64),
#  array([787, 792, 808, 801, 223,  51,   2], dtype=int64))

# %%
from numpy import argmax
g=sns.countplot(x=argmax(y_train,axis=1))
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '0'),
#  Text(1, 0, '1'),
#  Text(2, 0, '2'),
#  Text(3, 0, '3'),
#  Text(4, 0, '4'),
#  Text(5, 0, '5'),
#  Text(6, 0, '6')]

# %% [markdown]
# ## Check distribution of masterCategory in Test Data

# %%
np.unique(argmax(y_test,axis=1),return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5], dtype=int64),
#  array([213, 208, 192, 199,  44,  11], dtype=int64))

# %%
np.unique(argmax(y_test,axis=1),return_counts=True)
# Out:
# (array([0, 1, 2, 3, 4, 5], dtype=int64),
#  array([213, 208, 192, 199,  44,  11], dtype=int64))

# %%
from numpy import argmax
g=sns.countplot(x=argmax(y_test,axis=1))
g.set_xticklabels(g.get_xticklabels(), rotation=90)
# Out:
# [Text(0, 0, '0'),
#  Text(1, 0, '1'),
#  Text(2, 0, '2'),
#  Text(3, 0, '3'),
#  Text(4, 0, '4'),
#  Text(5, 0, '5')]

# %% [markdown]
# ## 3.1 Base Model

# %%
base_model = VGG16(weights="imagenet", include_top=False, input_shape=X_train[0].shape)
base_model.trainable = False ## Not trainable weights

# %% [markdown]
# ## 3.2 Build CNN model

# %%
def model_builder(hp):
    model = models.Sequential(layers=base_model.layers)
    model.add(layers.Flatten())

    # Tune the number of units in the first Dense layer
    # Choose an optimal value between 32-512
    #hp_units = hp.Int('units', min_value=10, max_value=50, step=20)
    hp_units = hp.Choice('units', values=[20,40,50])
    model.add(layers.Dense(units=hp_units, activation='relu'))
    model.add(layers.Dense(units=20, activation='relu'))   
    model.add(layers.Dense(7, activation='softmax'))

    # Tune the learning rate for the optimizer
    # Choose an optimal value from 0.01, 0.001, or 0.0001
    hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])

    model.compile(optimizer=keras.optimizers.Adam(learning_rate=hp_learning_rate),
                  loss='categorical_crossentropy',metrics=['accuracy'])

    return model

# %%
tuner = kt.RandomSearch(model_builder,objective='val_accuracy',max_trials=6)

# %% [markdown]
# ## 3.3 Hyperparameter Tuning

# %%
es = EarlyStopping(monitor='val_accuracy', mode='max', patience=5,  restore_best_weights=True)

tuner.search(X_train, y_train, epochs=5, validation_split=0.2, callbacks=[es])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
print(best_hps.values)
# Out:
# Trial 6 Complete [01h 14m 04s]
# val_accuracy: 0.9379509091377258
#
# Best val_accuracy So Far: 0.9567099809646606
# Total elapsed time: 09h 21m 38s
# INFO:tensorflow:Oracle triggered exit
# {'units': 20, 'learning_rate': 0.001}

# %%
tuner.search_space_summary()
# Out:
# Search space summary
# Default search space size: 2
# units (Choice)
# {'default': 20, 'conditions': [], 'values': [20, 40, 50], 'ordered': True}
# learning_rate (Choice)
# {'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}

# %%
tuner.get_best_models(num_models=1)[0].summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 20)                501780
#
#  dense_1 (Dense)             (None, 20)                420
#
#  dense_2 (Dense)             (None, 7)                 147
#
# =================================================================
# Total params: 15,217,035
# Trainable params: 502,347
# Non-trainable params: 14,714,688
# _________________________________________________________________
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.iter
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_1
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.beta_2
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.decay
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).optimizer.learning_rate

# %%
(best_hps.get('units'),best_hps.get('learning_rate'))
# Out:
# (20, 0.001)

# %%
print(best_hps)
# Out:
# <keras_tuner.engine.hyperparameters.hyperparameters.HyperParameters object at 0x0000020943EF7010>

# %% [markdown]
# ## 3.4 Train Model with Best Hyperparameters

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
hypermodel = tuner.hypermodel.build(best_hps)
history = hypermodel.fit(X_train, y_train, batch_size=10, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Epoch 1/50
# 278/278 [==============================] - 894s 3s/step - loss: 1.2141 - accuracy: 0.7618 - val_loss: 0.7254 - val_accuracy: 0.8571
# Epoch 2/50
# 278/278 [==============================] - 896s 3s/step - loss: 0.6416 - accuracy: 0.8614 - val_loss: 0.5206 - val_accuracy: 0.9048
# Epoch 3/50
# 278/278 [==============================] - 895s 3s/step - loss: 0.5082 - accuracy: 0.8697 - val_loss: 0.5525 - val_accuracy: 0.8427
# Epoch 4/50
# 278/278 [==============================] - 895s 3s/step - loss: 0.4442 - accuracy: 0.8824 - val_loss: 0.7100 - val_accuracy: 0.8874
# Epoch 5/50
# 278/278 [==============================] - 914s 3s/step - loss: 0.4069 - accuracy: 0.8921 - val_loss: 0.5236 - val_accuracy: 0.8947
# Epoch 6/50
# 278/278 [==============================] - 974s 4s/step - loss: 0.3913 - accuracy: 0.9008 - val_loss: 0.4119 - val_accuracy: 0.9091
# Epoch 7/50
# 278/278 [==============================] - 953s 3s/step - loss: 0.3579 - accuracy: 0.9062 - val_loss: 0.4376 - val_accuracy: 0.9105
# Epoch 8/50
# 278/278 [==============================] - 950s 3s/step - loss: 0.3649 - accuracy: 0.9073 - val_loss: 0.4966 - val_accuracy: 0.8990
# Epoch 9/50
# 278/278 [==============================] - 904s 3s/step - loss: 0.3438 - accuracy: 0.9091 - val_loss: 0.4274 - val_accuracy: 0.9134
# Epoch 10/50
# 278/278 [==============================] - 915s 3s/step - loss: 0.3326 - accuracy: 0.9159 - val_loss: 0.4410 - val_accuracy: 0.9163
# Epoch 11/50
# 278/278 [==============================] - 909s 3s/step - loss: 0.3567 - accuracy: 0.9195 - val_loss: 0.4622 - val_accuracy: 0.8975
# Epoch 12/50
# 278/278 [==============================] - 897s 3s/step - loss: 0.3662 - accuracy: 0.9101 - val_loss: 0.4924 - val_accuracy: 0.8903
# Epoch 13/50
# 278/278 [==============================] - 915s 3s/step - loss: 0.3216 - accuracy: 0.9202 - val_loss: 0.4380 - val_accuracy: 0.9149
# Epoch 14/50
# 278/278 [==============================] - 934s 3s/step - loss: 0.3170 - accuracy: 0.9224 - val_loss: 0.6075 - val_accuracy: 0.9163
# Epoch 15/50
# 278/278 [==============================] - 944s 3s/step - loss: 0.3685 - accuracy: 0.9137 - val_loss: 0.4291 - val_accuracy: 0.9149
# Epoch 16/50
# 278/278 [==============================] - 954s 3s/step - loss: 0.3211 - accuracy: 0.9282 - val_loss: 0.4189 - val_accuracy: 0.9264
# Epoch 17/50
# 278/278 [==============================] - 1080s 4s/step - loss: 0.3114 - accuracy: 0.9304 - val_loss: 0.4050 - val_accuracy: 0.9250
# Epoch 18/50
# 278/278 [==============================] - 905s 3s/step - loss: 0.3094 - accuracy: 0.9220 - val_loss: 0.7563 - val_accuracy: 0.8947
# Epoch 19/50
# 278/278 [==============================] - 896s 3s/step - loss: 0.3311 - accuracy: 0.9231 - val_loss: 0.4351 - val_accuracy: 0.9091
# Epoch 20/50
# 278/278 [==============================] - 894s 3s/step - loss: 0.3443 - accuracy: 0.9322 - val_loss: 0.4232 - val_accuracy: 0.9307
# Epoch 21/50
# 278/278 [==============================] - 897s 3s/step - loss: 0.2942 - accuracy: 0.9300 - val_loss: 0.4927 - val_accuracy: 0.9307
# Epoch 22/50
# 278/278 [==============================] - 898s 3s/step - loss: 0.3595 - accuracy: 0.9293 - val_loss: 0.3640 - val_accuracy: 0.9250
# Epoch 23/50
# 278/278 [==============================] - 896s 3s/step - loss: 0.2885 - accuracy: 0.9350 - val_loss: 0.4318 - val_accuracy: 0.9221
# Epoch 24/50
# 278/278 [==============================] - 899s 3s/step - loss: 0.2578 - accuracy: 0.9311 - val_loss: 0.4263 - val_accuracy: 0.9278
# Epoch 25/50
# 278/278 [==============================] - 898s 3s/step - loss: 0.2467 - accuracy: 0.9365 - val_loss: 0.6095 - val_accuracy: 0.9264
# Epoch 26/50
# 278/278 [==============================] - 900s 3s/step - loss: 0.2303 - accuracy: 0.9408 - val_loss: 0.5124 - val_accuracy: 0.9235
# Epoch 27/50
# 278/278 [==============================] - 926s 3s/step - loss: 0.2317 - accuracy: 0.9401 - val_loss: 0.5211 - val_accuracy: 0.9163
# Epoch 28/50
# 278/278 [==============================] - 909s 3s/step - loss: 0.3298 - accuracy: 0.9231 - val_loss: 0.4422 - val_accuracy: 0.9264
# Epoch 29/50
# 278/278 [==============================] - 933s 3s/step - loss: 0.3401 - accuracy: 0.9285 - val_loss: 0.5317 - val_accuracy: 0.9250
# Epoch 30/50
# 278/278 [==============================] - 947s 3s/step - loss: 0.2890 - accuracy: 0.9405 - val_loss: 0.5032 - val_accuracy: 0.9351
# Epoch 31/50
# 278/278 [==============================] - 952s 3s/step - loss: 0.2527 - accuracy: 0.9311 - val_loss: 0.3961 - val_accuracy: 0.9380
# Epoch 32/50
# 278/278 [==============================] - 945s 3s/step - loss: 0.2583 - accuracy: 0.9408 - val_loss: 0.5814 - val_accuracy: 0.9264
# Epoch 33/50
# 278/278 [==============================] - 957s 3s/step - loss: 0.2645 - accuracy: 0.9350 - val_loss: 0.4537 - val_accuracy: 0.9134
# Epoch 34/50
# 278/278 [==============================] - 947s 3s/step - loss: 0.2693 - accuracy: 0.9376 - val_loss: 0.5277 - val_accuracy: 0.9278
# Epoch 35/50
# 278/278 [==============================] - 944s 3s/step - loss: 0.2314 - accuracy: 0.9397 - val_loss: 0.4951 - val_accuracy: 0.9120
# Epoch 36/50
# 278/278 [==============================] - 935s 3s/step - loss: 0.2447 - accuracy: 0.9376 - val_loss: 0.5450 - val_accuracy: 0.9408
# Epoch 37/50
# 278/278 [==============================] - 971s 3s/step - loss: 0.2290 - accuracy: 0.9437 - val_loss: 0.5119 - val_accuracy: 0.8860
# Epoch 38/50
# 278/278 [==============================] - 957s 3s/step - loss: 0.2621 - accuracy: 0.9383 - val_loss: 0.6581 - val_accuracy: 0.9264
# Epoch 39/50
# 278/278 [==============================] - 944s 3s/step - loss: 0.2673 - accuracy: 0.9408 - val_loss: 0.6554 - val_accuracy: 0.9033
# Epoch 40/50
# 278/278 [==============================] - 908s 3s/step - loss: 0.2331 - accuracy: 0.9408 - val_loss: 0.5495 - val_accuracy: 0.9206
# Epoch 41/50
# 278/278 [==============================] - 903s 3s/step - loss: 0.2147 - accuracy: 0.9408 - val_loss: 0.6471 - val_accuracy: 0.9365
# Epoch 42/50
# 278/278 [==============================] - 901s 3s/step - loss: 0.2103 - accuracy: 0.9437 - val_loss: 0.5370 - val_accuracy: 0.9322
# Epoch 43/50
# 278/278 [==============================] - 901s 3s/step - loss: 0.2010 - accuracy: 0.9466 - val_loss: 0.5104 - val_accuracy: 0.9307
# Epoch 44/50
# 278/278 [==============================] - 896s 3s/step - loss: 0.1956 - accuracy: 0.9459 - val_loss: 0.5431 - val_accuracy: 0.9322
# Epoch 45/50
# 278/278 [==============================] - 899s 3s/step - loss: 0.2019 - accuracy: 0.9462 - val_loss: 0.5411 - val_accuracy: 0.9250
# Epoch 46/50
# 278/278 [==============================] - 899s 3s/step - loss: 0.1993 - accuracy: 0.9462 - val_loss: 0.7214 - val_accuracy: 0.9293
# Epoch 47/50
# 278/278 [==============================] - 897s 3s/step - loss: 0.2606 - accuracy: 0.9405 - val_loss: 0.4774 - val_accuracy: 0.9336
# Epoch 48/50
# 278/278 [==============================] - 897s 3s/step - loss: 0.2422 - accuracy: 0.9379 - val_loss: 0.6510 - val_accuracy: 0.9206
# Epoch 49/50
# 278/278 [==============================] - 898s 3s/step - loss: 0.2378 - accuracy: 0.9347 - val_loss: 0.6794 - val_accuracy: 0.9293
# Epoch 50/50
# 278/278 [==============================] - 896s 3s/step - loss: 0.2353 - accuracy: 0.9390 - val_loss: 0.5508 - val_accuracy: 0.9177
# Best epoch: 36

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_1st_tune_df = pd.DataFrame(history.history) 

# save to json:  
#hist_json_file = 'history.json' 
#with open(hist_json_file, mode='w') as f:
#    hist_df.to_json(f)

# or save to csv: 
file = 'first_tune_history.csv'
with open(file, mode='w') as f:
    hist_1st_tune_df.to_csv(f)

# %% [markdown]
# ## 3.5 Retrain Model with Best epochs

# %%
##Re-instantiate the hypermodel and train it with the optimal number of epochs from above.

hypermodel = tuner.hypermodel.build(best_hps)

# Retrain the model
history_final=hypermodel.fit(X_train, y_train, batch_size=10,epochs=best_epoch, validation_split=0.2)
# Out:
# Epoch 1/36
# 278/278 [==============================] - 6619s 24s/step - loss: 1.0512 - accuracy: 0.8004 - val_loss: 0.4896 - val_accuracy: 0.8889
# Epoch 2/36
# 278/278 [==============================] - 895s 3s/step - loss: 0.4692 - accuracy: 0.8842 - val_loss: 0.3481 - val_accuracy: 0.9134
# Epoch 3/36
# 278/278 [==============================] - 898s 3s/step - loss: 0.3602 - accuracy: 0.9101 - val_loss: 0.3945 - val_accuracy: 0.9120
# Epoch 4/36
# 278/278 [==============================] - 907s 3s/step - loss: 0.2400 - accuracy: 0.9195 - val_loss: 0.3725 - val_accuracy: 0.9105
# Epoch 5/36
# 278/278 [==============================] - 975s 4s/step - loss: 0.1961 - accuracy: 0.9379 - val_loss: 0.3638 - val_accuracy: 0.9437
# Epoch 6/36
# 278/278 [==============================] - 924s 3s/step - loss: 0.1633 - accuracy: 0.9470 - val_loss: 0.5146 - val_accuracy: 0.9380
# Epoch 7/36
# 278/278 [==============================] - 951s 3s/step - loss: 0.2016 - accuracy: 0.9433 - val_loss: 0.4782 - val_accuracy: 0.8889
# Epoch 8/36
# 278/278 [==============================] - 910s 3s/step - loss: 0.1838 - accuracy: 0.9311 - val_loss: 0.4629 - val_accuracy: 0.9481
# Epoch 9/36
# 278/278 [==============================] - 905s 3s/step - loss: 0.1618 - accuracy: 0.9513 - val_loss: 0.3684 - val_accuracy: 0.9336
# Epoch 10/36
# 278/278 [==============================] - 938s 3s/step - loss: 0.1494 - accuracy: 0.9571 - val_loss: 0.4281 - val_accuracy: 0.9423
# Epoch 11/36
# 278/278 [==============================] - 902s 3s/step - loss: 0.1079 - accuracy: 0.9603 - val_loss: 0.4114 - val_accuracy: 0.9481
# Epoch 12/36
# 278/278 [==============================] - 900s 3s/step - loss: 0.0988 - accuracy: 0.9654 - val_loss: 0.4640 - val_accuracy: 0.9481
# Epoch 13/36
# 278/278 [==============================] - 903s 3s/step - loss: 0.0968 - accuracy: 0.9675 - val_loss: 0.3796 - val_accuracy: 0.9365
# Epoch 14/36
# 278/278 [==============================] - 950s 3s/step - loss: 0.0862 - accuracy: 0.9682 - val_loss: 0.3619 - val_accuracy: 0.9495
# Epoch 15/36
# 278/278 [==============================] - 911s 3s/step - loss: 0.0782 - accuracy: 0.9729 - val_loss: 0.4660 - val_accuracy: 0.9466
# Epoch 16/36
# 278/278 [==============================] - 910s 3s/step - loss: 0.0708 - accuracy: 0.9744 - val_loss: 0.5139 - val_accuracy: 0.9437
# Epoch 17/36
# 278/278 [==============================] - 902s 3s/step - loss: 0.0679 - accuracy: 0.9744 - val_loss: 0.4303 - val_accuracy: 0.9495
# Epoch 18/36
# 278/278 [==============================] - 897s 3s/step - loss: 0.0963 - accuracy: 0.9686 - val_loss: 0.6541 - val_accuracy: 0.9380
# Epoch 19/36
# 278/278 [==============================] - 897s 3s/step - loss: 0.1684 - accuracy: 0.9531 - val_loss: 0.5103 - val_accuracy: 0.9452
# Epoch 20/36
# 278/278 [==============================] - 898s 3s/step - loss: 0.0913 - accuracy: 0.9679 - val_loss: 0.5011 - val_accuracy: 0.9524
# Epoch 21/36
# 278/278 [==============================] - 899s 3s/step - loss: 0.1213 - accuracy: 0.9690 - val_loss: 0.7098 - val_accuracy: 0.9394
# Epoch 22/36
# 278/278 [==============================] - 897s 3s/step - loss: 0.1000 - accuracy: 0.9729 - val_loss: 0.4678 - val_accuracy: 0.9452
# Epoch 23/36
# 278/278 [==============================] - 901s 3s/step - loss: 0.0842 - accuracy: 0.9737 - val_loss: 0.5299 - val_accuracy: 0.9524
# Epoch 24/36
# 278/278 [==============================] - 12636s 46s/step - loss: 0.0673 - accuracy: 0.9755 - val_loss: 0.5423 - val_accuracy: 0.9408
# Epoch 25/36
# 278/278 [==============================] - 924s 3s/step - loss: 0.0651 - accuracy: 0.9765 - val_loss: 0.5559 - val_accuracy: 0.9452
# Epoch 26/36
# 278/278 [==============================] - 912s 3s/step - loss: 0.0625 - accuracy: 0.9762 - val_loss: 0.5536 - val_accuracy: 0.9394
# Epoch 27/36
# 278/278 [==============================] - 912s 3s/step - loss: 0.0688 - accuracy: 0.9758 - val_loss: 0.5896 - val_accuracy: 0.9495
# Epoch 28/36
# 278/278 [==============================] - 912s 3s/step - loss: 0.0627 - accuracy: 0.9765 - val_loss: 0.5943 - val_accuracy: 0.9495
# Epoch 29/36
# 278/278 [==============================] - 908s 3s/step - loss: 0.0624 - accuracy: 0.9765 - val_loss: 0.5995 - val_accuracy: 0.9509
# Epoch 30/36
# 278/278 [==============================] - 908s 3s/step - loss: 0.0623 - accuracy: 0.9765 - val_loss: 0.6060 - val_accuracy: 0.9509
# Epoch 31/36
# 278/278 [==============================] - 914s 3s/step - loss: 0.0622 - accuracy: 0.9765 - val_loss: 0.6124 - val_accuracy: 0.9509
# Epoch 32/36
# 278/278 [==============================] - 911s 3s/step - loss: 0.0622 - accuracy: 0.9765 - val_loss: 0.6183 - val_accuracy: 0.9509
# Epoch 33/36
# 278/278 [==============================] - 907s 3s/step - loss: 0.0621 - accuracy: 0.9765 - val_loss: 0.6254 - val_accuracy: 0.9509
# Epoch 34/36
# 278/278 [==============================] - 898s 3s/step - loss: 0.0621 - accuracy: 0.9765 - val_loss: 0.6305 - val_accuracy: 0.9509
# Epoch 35/36
# 278/278 [==============================] - 900s 3s/step - loss: 0.0621 - accuracy: 0.9765 - val_loss: 0.6373 - val_accuracy: 0.9509
# Epoch 36/36
# 278/278 [==============================] - 906s 3s/step - loss: 0.0620 - accuracy: 0.9765 - val_loss: 0.6445 - val_accuracy: 0.9509

# %%
# convert the history.history dict to a pandas DataFrame:     
hist_2nd_tune_df = pd.DataFrame(history_final.history) 

# save to json:  
#hist_json_file = 'history.json' 
#with open(hist_json_file, mode='w') as f:
#    hist_df.to_json(f)

# or save to csv: 
file1 = 'epoch_10_history_with_Tuning.csv'
with open(file1, mode='w') as f:
    hist_2nd_tune_df.to_csv(f)

# %%
hist_2nd_tune_df
# Out:
#         loss  accuracy  val_loss  val_accuracy
# 0   1.051193  0.800433  0.489597      0.888889
# 1   0.469187  0.884157  0.348150      0.913420
# 2   0.360161  0.910141  0.394474      0.911977
# 3   0.239998  0.919524  0.372537      0.910534
# 4   0.196094  0.937929  0.363838      0.943723
# 5   0.163312  0.946951  0.514619      0.937951
# 6   0.201576  0.943342  0.478167      0.888889
# 7   0.183804  0.931072  0.462937      0.948052
# 8   0.161833  0.951281  0.368423      0.933622
# 9   0.149424  0.957055  0.428136      0.942280
# 10  0.107919  0.960303  0.411412      0.948052
# 11  0.098756  0.965355  0.463961      0.948052
# 12  0.096828  0.967521  0.379630      0.936508
# 13  0.086249  0.968243  0.361898      0.949495
# 14  0.078161  0.972934  0.466025      0.946609
# 15  0.070774  0.974377  0.513902      0.943723
# 16  0.067867  0.974377  0.430254      0.949495
# 17  0.096277  0.968603  0.654081      0.937951
# 18  0.168437  0.953086  0.510321      0.945166
# 19  0.091273  0.967882  0.501058      0.952381
# 20  0.121267  0.968964  0.709803      0.939394
# 21  0.100008  0.972934  0.467803      0.945166
# 22  0.084173  0.973656  0.529902      0.952381
# 23  0.067334  0.975460  0.542342      0.940837
# 24  0.065092  0.976543  0.555937      0.945166
# 25  0.062464  0.976182  0.553589      0.939394
# 26  0.068804  0.975821  0.589639      0.949495
# 27  0.062721  0.976543  0.594301      0.949495
# 28  0.062362  0.976543  0.599518      0.950938
# 29  0.062340  0.976543  0.606045      0.950938
# 30  0.062215  0.976543  0.612409      0.950938
# 31  0.062192  0.976543  0.618340      0.950938
# 32  0.062136  0.976543  0.625443      0.950938
# 33  0.062145  0.976543  0.630498      0.950938
# 34  0.062077  0.976543  0.637292      0.950938
# 35  0.062019  0.976543  0.644498      0.950938

# %% [markdown]
# ## 3.6 Model Evalution

# %% [markdown]
# ### Loss and Accuracy Scores

# %%
# evaluate hypermodel on test data
test_scores = hypermodel.evaluate(X_test, y_test, batch_size=10,verbose=0)
print("[test loss, test accuracy]:", test_scores)
# Out:
# [test loss, test accuracy]: [0.7647724151611328, 0.9446367025375366]

# %% [markdown]
# ### Loss and Accuracy Plots

# %%
# summarize history for accuracy
plt.plot(history_final.history['accuracy'])
plt.plot(history_final.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history_final.history['loss'])
plt.plot(history_final.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
#check the environment jupyter notebook is running 

#import sys
#print(sys.executable)

# %% [markdown]
# ### Classification Reports on Test Data

# %%
y_pred = hypermodel.predict(X_test)               ## xtest => test image
y_test_class = np.argmax(y_test, axis=1)     ## ytest => test image's label
y_pred_class=np.argmax(y_pred, axis=1) 
print(classification_report(y_test_class, y_pred_class))
print(confusion_matrix(y_test_class, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       213
#            1       0.90      0.94      0.92       208
#            2       1.00      0.99      0.99       192
#            3       0.99      0.98      0.99       199
#            4       0.55      0.66      0.60        44
#            5       0.00      0.00      0.00        11
#
#     accuracy                           0.94       867
#    macro avg       0.74      0.76      0.75       867
# weighted avg       0.94      0.94      0.94       867
#
# [[208   3   0   0   2   0]
#  [  1 196   0   0  11   0]
#  [  1   0 190   0   1   0]
#  [  0   3   0 196   0   0]
#  [  0  14   0   1  29   0]
#  [  0   1   0   0  10   0]]

# %% [markdown]
# ## 3.7 Save Hypermodel

# %%
# serialize model to JSON
hypermodel_json = hypermodel.to_json()
with open("hypermodel.json", "w") as json_file:
    json_file.write(hypermodel_json)
    
# serialize weights to HDF5
hypermodel.save_weights("hypermodel.h5")
print("Saved hypermodel to disk")
# Out:
# Saved hypermodel to disk

# %% [markdown]
# ## 3.8 Load Hypermodel

# %%
# load json and create model
json_file = open('hypermodel.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
hypermodel = model_from_json(loaded_model_json)
# load weights into new model
model.load_weights("hypermodel.h5")
print("Loaded hypermodel from disk")
# Out:
# Loaded model from disk

# %%
hypermodel.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy'])
